# %%
import numpy as np

from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier


X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False, parser="pandas")
X = X / 255.0
y = np.int_(y)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0, test_size=0.7)

# %%
mlp_clf = MLPClassifier(
    solver="lbfgs",
    verbose=10,
)

mlp_clf.fit(X_train, y_train)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =        79510     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.41582D+00    |proj g|=  4.79419D-02
#
# At iterate    1    f=  1.88838D+00    |proj g|=  8.39252D-02
#
# At iterate    2    f=  1.36393D+00    |proj g|=  6.45593D-02
#
# At iterate    3    f=  8.80145D-01    |proj g|=  1.07684D-01
#
# At iterate    4    f=  7.03716D-01    |proj g|=  1.85323D-01
#
# At iterate    5    f=  6.01071D-01    |proj g|=  7.95637D-02
#
# At iterate    6    f=  5.70435D-01    |proj g|=  3.90532D-02
#
# At iterate    7    f=  5.47462D-01    |proj g|=  3.08738D-02
#
# At iterate    8    f=  5.20300D-01    |proj g|=  4.45975D-02
#
# At iterate    9    f=  5.11386D-01    |proj g|=  1.50620D-01
#
# At iterate   10    f=  4.69836D-01    |proj g|=  3.00069D-02
#
# At iterate   11    f=  4.53198D-01    |proj g|=  2.32219D-02
#
# At iterate   12    f=  4.25801D-01    |proj g|=  3.60508D-02
#
# At iterate   13    f=  4.02914D-01    |proj g|=  3.42440D-02
#
# At iterate   14    f=  3.88931D-01    |proj g|=  6.39019D-02
#
# At iterate   15    f=  3.61381D-01    |proj g|=  4.32716D-02
#
# At iterate   16    f=  3.50818D-01    |proj g|=  2.52896D-02
#
# At iterate   17    f=  3.36304D-01    |proj g|=  1.57393D-02
#
# At iterate   18    f=  3.30473D-01    |proj g|=  4.19613D-02
#
# At iterate   19    f=  3.23068D-01    |proj g|=  2.04710D-02
#
# At iterate   20    f=  3.11831D-01    |proj g|=  1.42786D-02
#
# At iterate   21    f=  2.99627D-01    |proj g|=  3.07423D-02
#
# At iterate   22    f=  2.89372D-01    |proj g|=  1.79256D-02
#
# At iterate   23    f=  2.82040D-01    |proj g|=  1.08058D-02
#
# At iterate   24    f=  2.75074D-01    |proj g|=  1.22271D-02
#
# At iterate   25    f=  2.65585D-01    |proj g|=  4.14588D-02
#
# At iterate   26    f=  2.54420D-01    |proj g|=  3.12158D-02
#
# At iterate   27    f=  2.37426D-01    |proj g|=  1.08267D-02
#
# At iterate   28    f=  2.32560D-01    |proj g|=  1.74124D-02
#
# At iterate   29    f=  2.26513D-01    |proj g|=  1.87593D-02
#
# At iterate   30    f=  2.16254D-01    |proj g|=  2.29482D-02
#
# At iterate   31    f=  2.12970D-01    |proj g|=  3.39976D-02
#
# At iterate   32    f=  2.06526D-01    |proj g|=  8.50378D-03
#
# At iterate   33    f=  2.04190D-01    |proj g|=  7.98255D-03
#
# At iterate   34    f=  1.99445D-01    |proj g|=  1.37574D-02
#
# At iterate   35    f=  1.89456D-01    |proj g|=  1.91381D-02
#
# At iterate   36    f=  1.83125D-01    |proj g|=  2.94125D-02
#
# At iterate   37    f=  1.73600D-01    |proj g|=  1.10977D-02
#
# At iterate   38    f=  1.68596D-01    |proj g|=  8.04337D-03
#
# At iterate   39    f=  1.63599D-01    |proj g|=  1.08725D-02
#
# At iterate   40    f=  1.57441D-01    |proj g|=  9.95210D-03
#
# At iterate   41    f=  1.49300D-01    |proj g|=  1.38025D-02
#
# At iterate   42    f=  1.46386D-01    |proj g|=  4.79414D-02
#
# At iterate   43    f=  1.38174D-01    |proj g|=  6.10332D-03
#
# At iterate   44    f=  1.35999D-01    |proj g|=  8.06882D-03
#
# At iterate   45    f=  1.31604D-01    |proj g|=  1.16621D-02
#
# At iterate   46    f=  1.28768D-01    |proj g|=  2.72028D-02
#
# At iterate   47    f=  1.23419D-01    |proj g|=  6.40051D-03
#
# At iterate   48    f=  1.19224D-01    |proj g|=  8.08590D-03
#
# At iterate   49    f=  1.15829D-01    |proj g|=  1.10803D-02
#
# At iterate   50    f=  1.08270D-01    |proj g|=  1.20489D-02
#
# At iterate   51    f=  1.03995D-01    |proj g|=  2.35400D-02
#
# At iterate   52    f=  9.84575D-02    |proj g|=  1.10143D-02
#
# At iterate   53    f=  9.51703D-02    |proj g|=  8.65943D-03
#
# At iterate   54    f=  9.24033D-02    |proj g|=  5.52320D-03
#
# At iterate   55    f=  8.91193D-02    |proj g|=  7.59121D-03
#
# At iterate   56    f=  8.36459D-02    |proj g|=  8.68112D-03
#
# At iterate   57    f=  8.28203D-02    |proj g|=  3.00185D-02
#
# At iterate   58    f=  7.67003D-02    |proj g|=  6.42989D-03
#
# At iterate   59    f=  7.44474D-02    |proj g|=  3.18655D-03
#
# At iterate   60    f=  7.14980D-02    |proj g|=  6.73671D-03
#
# At iterate   61    f=  6.86160D-02    |proj g|=  1.37627D-02
#
# At iterate   62    f=  6.49274D-02    |proj g|=  6.69750D-03
#
# At iterate   63    f=  6.18012D-02    |proj g|=  6.48257D-03
#
# At iterate   64    f=  5.83097D-02    |proj g|=  5.91962D-03
#
# At iterate   65    f=  5.37124D-02    |proj g|=  8.59439D-03
#
# At iterate   66    f=  5.18285D-02    |proj g|=  1.53200D-02
#
# At iterate   67    f=  4.66463D-02    |proj g|=  3.97218D-03
#
# At iterate   68    f=  4.50312D-02    |proj g|=  3.46726D-03
#
# At iterate   69    f=  4.22520D-02    |proj g|=  7.02062D-03
#
# At iterate   70    f=  4.10981D-02    |proj g|=  2.29038D-02
#
# At iterate   71    f=  3.78092D-02    |proj g|=  3.50038D-03
#
# At iterate   72    f=  3.60209D-02    |proj g|=  3.15811D-03
#
# At iterate   73    f=  3.38751D-02    |proj g|=  5.95001D-03
#
# At iterate   74    f=  3.22967D-02    |proj g|=  1.76194D-02
#
# At iterate   75    f=  2.96233D-02    |proj g|=  4.32663D-03
#
# At iterate   76    f=  2.79506D-02    |proj g|=  2.42613D-03
#
# At iterate   77    f=  2.63028D-02    |proj g|=  6.00191D-03
#
# At iterate   78    f=  2.42606D-02    |proj g|=  7.02071D-03
#
# At iterate   79    f=  2.23388D-02    |proj g|=  6.99382D-03
#
# At iterate   80    f=  2.06819D-02    |proj g|=  2.22591D-03
#
# At iterate   81    f=  1.96436D-02    |proj g|=  3.71068D-03
#
# At iterate   82    f=  1.78599D-02    |proj g|=  3.49241D-03
#
# At iterate   83    f=  1.68944D-02    |proj g|=  1.08780D-02
#
# At iterate   84    f=  1.52243D-02    |proj g|=  1.70735D-03
#
# At iterate   85    f=  1.41028D-02    |proj g|=  2.46783D-03
#
# At iterate   86    f=  1.29025D-02    |proj g|=  3.26744D-03
#
# At iterate   87    f=  1.08804D-02    |proj g|=  3.51797D-03
#
# At iterate   88    f=  9.78431D-03    |proj g|=  4.22162D-03
#
# At iterate   89    f=  8.43708D-03    |proj g|=  1.82371D-03
#
# At iterate   90    f=  7.49506D-03    |proj g|=  9.65038D-04
#
# At iterate   91    f=  6.41282D-03    |proj g|=  2.81664D-03
#
# At iterate   92    f=  5.54830D-03    |proj g|=  2.32885D-03
#
# At iterate   93    f=  5.02317D-03    |proj g|=  1.47870D-03
#
# At iterate   94    f=  4.54229D-03    |proj g|=  9.50337D-04
#
# At iterate   95    f=  4.02825D-03    |proj g|=  7.82384D-04
#
# At iterate   96    f=  3.62007D-03    |proj g|=  3.06385D-03
#
# At iterate   97    f=  3.07981D-03    |proj g|=  1.29586D-03
#
# At iterate   98    f=  2.58148D-03    |proj g|=  7.08541D-04
#
# At iterate   99    f=  2.15778D-03    |proj g|=  1.39004D-03
#
# At iterate  100    f=  1.85189D-03    |proj g|=  1.20738D-03
#
# At iterate  101    f=  1.64829D-03    |proj g|=  8.36209D-04
#
# At iterate  102    f=  1.34053D-03    |proj g|=  4.00594D-04
#
# At iterate  103    f=  1.06245D-03    |proj g|=  6.17693D-04
#
# At iterate  104    f=  7.81147D-04    |proj g|=  3.60781D-04
#
# At iterate  105    f=  6.27293D-04    |proj g|=  2.52899D-04
#
# At iterate  106    f=  5.15333D-04    |proj g|=  1.58208D-04
#
# At iterate  107    f=  4.41361D-04    |proj g|=  8.10612D-04
#
# At iterate  108    f=  3.38503D-04    |proj g|=  1.70457D-04
#
# At iterate  109    f=  3.01512D-04    |proj g|=  9.07044D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
# 79510    109    115      1     0     0   9.070D-05   3.015D-04
#   F =   3.0151182122426000E-004
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# MLPClassifier(solver='lbfgs', verbose=10)

# %%
from sklearn.metrics import confusion_matrix, balanced_accuracy_score


y_pred = mlp_clf.predict(X_test)
print("Confusion Matrix")
print(confusion_matrix(y_test, y_pred))
print("Balanced Accuracy Score")
print(balanced_accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix
# [[4781    2   15    6   10   13   30   10   24   20]
#  [   0 5466   20   17   13    1    3    8   10    6]
#  [  21   13 4725   24   33    4   14   32   24    6]
#  [   3   10   67 4735    2   70    4   24   49   22]
#  [   4   10   11    4 4605    6   20   19   12   77]
#  [  20   10    9   64    8 4168   28   12   42   23]
#  [  16   11   18    3   24   24 4646   11   27    0]
#  [   0   23   53   19   26    9    3 4882   11   46]
#  [  20   36   29   41   17   44   13    7 4524   26]
#  [  16    6    2   35   90   39    4   80   29 4601]]
# Balanced Accuracy Score
# 0.9614857809673067
