# %%
import pandas as pd


path = 'data\jena_climate\jena_climate_2009_2016.csv'

df = pd.read_csv(path)

# %%
import seaborn as sns


sns.relplot(df.iloc[:10000:100, :], x="Date Time", y="T (degC)", kind="line")
