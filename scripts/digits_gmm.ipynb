# %%
from sklearn.datasets import fetch_openml

X, y = fetch_openml("mnist_784", version=1, return_X_y=True, as_frame=False)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/ml/lib/python3.11/site-packages/sklearn/datasets/_openml.py:110: UserWarning: A network error occurred while downloading https://api.openml.org/api/v1/json/data/list/data_name/mnist_784/limit/2/data_version/1. Retrying...
#   warn(
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml/lib/python3.11/urllib/request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml/lib/python3.11/http/client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
# ...

# %%
from matplotlib import pyplot as plt

fig, ax = plt.subplots(10, 10, figsize=(28, 28))
for idx, axi in enumerate(ax.flat):
    im = axi.imshow(X[idx].reshape(28, 28), cmap='binary')

# %%
from tqdm import tqdm
import numpy as np
from sklearn.mixture import GaussianMixture

n_components = np.arange(50, 500, 10)
models = [GaussianMixture(n_components=n, covariance_type='full') for n in n_components]

aics = []
for model in tqdm(models):
    aics.append(model.fit(X[0:50]).aic(X))

# plt.plot(n_components, aics);
# Out:
#   2%|▏         | 1/45 [00:53<39:12, 53.46s/it]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 10
#       8 aics = []
#       9 for model in tqdm(models):
# ---> 10     aics.append(model.fit(X[0:50]).aic(X))
#      12 # plt.plot(n_components, aics);
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ml/lib/python3.11/site-packages/sklearn/mixture/_base.py:181, in BaseMixture.fit(self, X, y)
#     155 """Estimate model parameters with the EM algorithm.
#     156
#     157 The method fits the model ``n_init`` times and sets the parameters with
#    (...)
#     178     The fitted mixture.
#     179 """
#     180 # parameters are validated in fit_predict
# --> 181 self.fit_predict(X, y)
#     182 return self
#
# ...
