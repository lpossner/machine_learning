# %%
import numpy as np
import seaborn as sns
from scipy.stats import shapiro

# %%
N = 1000
k = 0.5

X = np.linspace(-1, 1, N).reshape(N, -1)
Y = k * X + np.random.normal(loc=0, scale=0.5, size=(N, 1))

sns.scatterplot(x=X.squeeze(), y=Y.squeeze())
# Out:
# <Axes: >

# %%
# X --> Y

k_est = np.linalg.inv(X.T @ X) @ X.T @ Y

Y_est = k_est * X
Y_res = Y - Y_est

sns.scatterplot(x=X.squeeze(), y=Y_res.squeeze())
# Out:
# <Axes: >

# %%
# X --> Y

k_est = np.linalg.inv(Y.T @ Y) @ Y.T @ X

X_est = k_est * Y
X_res = X - X_est

sns.scatterplot(x=Y.squeeze(), y=X_res.squeeze())
# Out:
# <Axes: >

# %%
shapiro(Y_res)
# Out:
# ShapiroResult(statistic=0.9988178610801697, pvalue=0.7664176821708679)

# %%
shapiro(X_res)
# Out:
# ShapiroResult(statistic=0.9905504584312439, pvalue=4.924535005557118e-06)
